# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib 
import seaborn as sns
# Out:
# Using matplotlib backend: agg

# %%
df=pd.read_csv('winequalityN.csv')

# %%
df1=df.head(100)
df1
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0             0.270         0.36            20.7
# 1   white            6.3             0.300         0.34             1.6
# 2   white            8.1             0.280         0.40             6.9
# 3   white            7.2             0.230         0.32             8.5
# 4   white            7.2             0.230         0.32             8.5
# ..    ...            ...               ...          ...             ...
# 95  white            7.1             0.260         0.29            12.4
# 96  white            6.0             0.340         0.66            15.9
# 97  white            8.6             0.265         0.36             1.2
# 98  white            9.8             0.360         0.46            10.5
# 99  white            6.0             0.340         0.66            15.9
#
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df1.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      99.000000         99.000000   100.000000       99.000000
# mean        6.998990          0.286919     0.348300        5.836364
# std         0.691862          0.106267     0.128881        5.346775
# min         5.800000          0.120000     0.030000        0.900000
# 25%         6.600000          0.230000     0.280000        1.400000
# 50%         7.000000          0.260000     0.340000        4.400000
# 75%         7.300000          0.320000     0.400000        8.900000
# max         9.800000          0.670000     0.660000       20.700000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  99.000000           100.000000            100.000000  100.000000
# mean    0.052545            35.385000            140.305000    0.994222
# std     0.022744            15.244945             43.044368    0.002728
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  100 non-null    object
#  1   fixed acidity         99 non-null     float64
#  2   volatile acidity      99 non-null     float64
#  3   citric acid           100 non-null    float64
#  4   residual sugar        99 non-null     float64
#  5   chlorides             99 non-null     float64
#  6   free sulfur dioxide   100 non-null    float64
#  7   total sulfur dioxide  100 non-null    float64
#  8   density               100 non-null    float64
#  9   pH                    99 non-null     float64
#  10  sulphates             100 non-null    float64
#  11  alcohol               100 non-null    float64
#  12  quality               100 non-null    int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 10.3+ KB

# %%
df1.shape
# Out:
# (100, 13)

# %%
df1.nunique()
# Out:
# type                     1
# fixed acidity           24
# volatile acidity        35
# citric acid             36
# residual sugar          49
# chlorides               40
# free sulfur dioxide     45
# total sulfur dioxide    70
# density                 51
# pH                      43
# sulphates               32
# alcohol                 37
# quality                  5
# dtype: int64

# %%
d=df1['chlorides'].mean()
d
# Out:
# 0.052545454545454555

# %%
df1.isnull().sum()
# Out:
# type                    0
# fixed acidity           1
# volatile acidity        1
# citric acid             0
# residual sugar          1
# chlorides               1
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.bar(df1['fixed acidity'],df1['residual sugar'] ,color='b')
plt.xlabel("fixed acidity")
plt.ylabel("residual sugar")
plt.title("Wine Quality")
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
df1.plot.bar(stacked=True)

# %%
df1.plot(kind='bar')

# %%
df1.plot.area()

# %%
plt.hist(df1['density'],color='blue')
plt.title('density histogram')
# Out:
# Text(0.5, 1.0, 'density histogram')

# %%
sns.displot(df1['total sulfur dioxide'],bins=30)

# %%
sns.heatmap(df1.corr())

# %%
x='y'
df1.plot(kind="scatter",x="pH",y="alcohol")

# %%
df1.plot.box()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
x=df1.quality
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f74612b4b90>,
# ...
#  [Text(1.099446196622535, 0.0349007268153815, ''),
#   Text(1.0950191148396637, 0.10456164753751468, ''),
#   Text(1.0861827775697164, 0.17380153541018023, ''),
#   Text(1.0729727656240828, 0.242341585843221, ''),
#   Text(1.0554422710583775, 0.3099058122448407, ''),
#   Text(1.0336618829868065, 0.37622215732219944, ''),
#   Text(1.0077193033447183, 0.4410235885601086, ''),
#   Text(0.9777189937438652, 0.5040491734667203, ''),
#   Text(0.9437817548423627, 0.5650451302565757, ''),
#   Text(0.9060442399230757, 0.623765849740282, ''),
#   Text(0.8682425975637968, 0.6753923243387291, ''),
#   Text(0.8313245312148797, 0.7203468080031734, ''),
#   Text(0.7920816079484067, 0.7632867916778509, ''),
#   Text(0.7420762513086384, 0.8119869686415656, ''),
#   Text(0.6890828155216029, 0.8574175606743897, ''),
#   Text(0.6333146864491143, 0.899395634816992, ''),
#   Text(0.5700287489232966, 0.940780115330326, ''),
# ...

# %%
plt.polar(x)

# %%
plt.plot(x,y)

# %%
df1.plot.barh(stacked=True)

# %%
df1.plot.hist(stacked=True, bins=20);

# %%
df1["alcohol"].plot.hist(orientation="horizontal", cumulative=True);
